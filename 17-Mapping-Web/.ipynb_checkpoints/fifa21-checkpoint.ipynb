# %%
import pandas as pd
import numpy as np

# %%
# Setting low_memory=False prevents this warning in pink: 
# "DtypeWarning: Columns ___ have mixed types.  Specify dtype option on import or set low_memory=False."
# Read in the csv:

fifa21 = pd.read_csv("fifa21_male2.csv", low_memory=False)
fifa21.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# 0  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1  17+0   Male
# 1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1  17+1   Male
# 2   54+0   54+0   52+0   47+0  46+0  46+0  46+0   47+0  15+0   Male
# 3   65+0   65+0   56+0   57+0  51+0  51+0  51+0   57+0  22+0   Male
# 4   73+3   73+3   70+3   67+3  64+3  64+3  64+3   67+3  17+3   Male
#
# [5 rows x 107 columns]

# %%
fifa21.shape
# Out:
# (17125, 107)

# %%
# Drop the players that are rated less than 75:

fifa21 = fifa21[fifa21['OVA'] >=75]

# %%
# See how many rows left:

fifa21.shape
# Out:
# (17125, 107)

# %%
columns = list(fifa21.columns)  # To print all the columns
print(columns)
# Out:
# ['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position', 'Player Photo', 'Club Logo', 'Flag Photo', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot', 'Growth', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats', 'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender']

# %%
# Gather unneeded columns to drop: 

useless_columns = ['ID', 'Club Logo', 'Growth', 'Loan Date End', 'Release Clause', 'Contract', 'W/F', 'SM', 'A/W', \
                   'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', \
                   'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', \
                   'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender']

# %%
# Drop the unneeded columns:

fifa21 = fifa21.drop(useless_columns, axis = 1)
fifa21.head()
# Out:
#           Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2      J. Cole   33   71                England  Coventry City   71  CAM
# 3     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                 Flag Photo  ...  Standing Tackle  \
# 0      https://cdn.sofifa.com/flags/it.png  ...               69
# 1      https://cdn.sofifa.com/flags/es.png  ...               43
# 2  https://cdn.sofifa.com/flags/gb-eng.png  ...               34
# 3      https://cdn.sofifa.com/flags/tt.png  ...               41
# 4      https://cdn.sofifa.com/flags/es.png  ...               57
#
#   Sliding Tackle Goalkeeping GK Diving GK Handling GK Kicking GK Positioning  \
# 0           69.0          56        14           5         15             10
# 1           40.0          56         9          12         13             11
# 2           30.0          51         9           6         13             16
# 3            NaN          68         5          21         64             21
# 4           56.0          45         6          13          6             13
#
#   GK Reflexes  Total Stats  Base Stats
# 0          12         1929         408
# 1          11         1906         385
# 2           7         1770         354
# 3          21         1348         369
# 4           7         2014         420
#
# [5 rows x 61 columns]

# %%
# See what Value columns looks like.  Needs some cleaning.
fifa21['Value']
# Out:
# 0        €625K
# 1        €600K
# 2        €1.1M
# 3           €0
# 4        €5.5M
#          ...
# 17120    €550K
# 17121    €130K
# 17122    €130K
# 17123    €475K
# 17124    €325K
# Name: Value, Length: 17125, dtype: object

# %%
# Drop the Euro symbol
fifa21['Value'] = fifa21['Value'].str[1:]
fifa21['Value']
# Out:
# 0        625K
# 1        600K
# 2        1.1M
# 3           0
# 4        5.5M
#          ...
# 17120    550K
# 17121    130K
# 17122    130K
# 17123    475K
# 17124    325K
# Name: Value, Length: 17125, dtype: object

# %%
# Convert Value from "625K", "5.5M", etc. to just numbers:

fifa21.Value = (fifa21.Value.replace(r'[KM]+$', '', regex=True).astype(float) * \
          fifa21.Value.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
fifa21['Value']
# Out:
# 0         625000.0
# 1         600000.0
# 2        1100000.0
# 3              0.0
# 4        5500000.0
#            ...
# 17120     550000.0
# 17121     130000.0
# 17122     130000.0
# 17123     475000.0
# 17124     325000.0
# Name: Value, Length: 17125, dtype: float64

# %%
# Look at the Wage column:
fifa21['Wage']
# Out:
# 0         €7K
# 1         €7K
# 2        €15K
# 3          €0
# 4        €12K
#          ...
# 17120     €2K
# 17121     €3K
# 17122     €2K
# 17123     €3K
# 17124     €2K
# Name: Wage, Length: 17125, dtype: object

# %%
# Now clean the Wage column:
# Drop the Euro sign
fifa21['Wage'] = fifa21['Wage'].str[1:]

# %%
# Convert Value from "625K", "5.5M", etc. to just numbers:
fifa21.Wage = (fifa21.Wage.replace(r'[KM]+$', '', regex=True).astype(float) * \
          fifa21.Wage.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
# Look at Wage again:

fifa21['Wage']
# Out:
# 0         7000.0
# 1         7000.0
# 2        15000.0
# 3            0.0
# 4        12000.0
#           ...
# 17120     2000.0
# 17121     3000.0
# 17122     2000.0
# 17123     3000.0
# 17124     2000.0
# Name: Wage, Length: 17125, dtype: float64

# %%
# Look at the Weight column:
fifa21['Weight']
# Out:
# 0        181lbs
# 1        143lbs
# 2        161lbs
# 3        165lbs
# 4        150lbs
#           ...
# 17120    165lbs
# 17121    170lbs
# 17122    154lbs
# 17123    148lbs
# 17124    154lbs
# Name: Weight, Length: 17125, dtype: object

# %%
# Drop 'lbs' from the weight column and change it from a string to integer:

fifa21['Weight'] = fifa21['Weight'].str[:3].astype(int)
fifa21['Weight']
# Out:
# 0        181
# 1        143
# 2        161
# 3        165
# 4        150
#         ...
# 17120    165
# 17121    170
# 17122    154
# 17123    148
# 17124    154
# Name: Weight, Length: 17125, dtype: int32

# %%
# Change Height to inches:

def parse_ht(ht):
    # format: 7' 0.0"
    ht_ = ht.split("'")
    ft_ = float(ht_[0])
    in_ = float(ht_[1].replace("\"",""))
    return (12*ft_) + in_

fifa21['inches'] = fifa21['Height'].apply(lambda x:parse_ht(x)).astype(int)

# %%
fifa21['inches']
# Out:
# 0        72
# 1        70
# 2        69
# 3        71
# 4        67
#          ..
# 17120    78
# 17121    70
# 17122    69
# 17123    69
# 17124    70
# Name: inches, Length: 17125, dtype: int32

# %%
# Calculate a bmi in case we want to analyze players that way:

fifa21['bmi'] = ((fifa21['Weight'] / (fifa21['inches']**2)) * 703).round(1)

# %%
fifa21['bmi']
# Out:
# 0        24.5
# 1        20.5
# 2        23.8
# 3        23.0
# 4        23.5
#          ...
# 17120    19.1
# 17121    24.4
# 17122    22.7
# 17123    21.9
# 17124    22.1
# Name: bmi, Length: 17125, dtype: float64

# %%
# Move the new inches column from the right side so it's next to height:

fifa21 = fifa21[['Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position',
       'Player Photo', 'Flag Photo', 'POT', 'Team & Contract', 'Height', 'inches',
       'Weight', 'bmi', 'foot', 'Joined', 'Value', 'Wage', 'Attacking', 'Crossing',
       'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill',
       'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
       'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions',
       'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
       'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning',
       'Vision', 'Penalties', 'Composure', 'Defending', 'Marking',
       'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving',
       'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
       'Total Stats', 'Base Stats']]

# %%
fifa21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17125 entries, 0 to 17124
# Data columns (total 63 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              17125 non-null  object
#  1   Age               17125 non-null  int64
#  2   OVA               17125 non-null  int64
#  3   Nationality       17125 non-null  object
#  4   Club              17102 non-null  object
#  5   BOV               17125 non-null  int64
#  6   BP                17125 non-null  object
#  7   Position          16712 non-null  object
#  8   Player Photo      17125 non-null  object
#  9   Flag Photo        17125 non-null  object
#  10  POT               17125 non-null  int64
#  11  Team & Contract   17125 non-null  object
#  12  Height            17125 non-null  object
#  13  inches            17125 non-null  int32
#  14  Weight            17125 non-null  int32
#  15  bmi               17125 non-null  float64
#  16  foot              17125 non-null  object
#  17  Joined            17067 non-null  object
#  18  Value             17125 non-null  float64
#  19  Wage              17125 non-null  float64
#  20  Attacking         17125 non-null  int64
#  21  Crossing          17125 non-null  int64
#  22  Finishing         17125 non-null  int64
#  23  Heading Accuracy  17125 non-null  int64
#  24  Short Passing     17125 non-null  int64
#  25  Volleys           17067 non-null  float64
#  26  Skill             17125 non-null  int64
#  27  Dribbling         17125 non-null  int64
#  28  Curve             17067 non-null  float64
#  29  FK Accuracy       17125 non-null  int64
#  30  Long Passing      17125 non-null  int64
#  31  Ball Control      17125 non-null  int64
#  32  Movement          17125 non-null  int64
#  33  Acceleration      17125 non-null  int64
#  34  Sprint Speed      17125 non-null  int64
#  35  Agility           17067 non-null  float64
#  36  Reactions         17125 non-null  int64
#  37  Balance           17067 non-null  float64
#  38  Power             17125 non-null  int64
#  39  Shot Power        17125 non-null  int64
#  40  Jumping           17067 non-null  float64
#  41  Stamina           17125 non-null  int64
#  42  Strength          17125 non-null  int64
#  43  Long Shots        17125 non-null  int64
#  44  Mentality         17125 non-null  int64
#  45  Aggression        17125 non-null  int64
#  46  Interceptions     17118 non-null  float64
#  47  Positioning       17118 non-null  float64
#  48  Vision            17067 non-null  float64
#  49  Penalties         17125 non-null  int64
#  50  Composure         16702 non-null  float64
#  51  Defending         17125 non-null  int64
#  52  Marking           17125 non-null  int64
#  53  Standing Tackle   17125 non-null  int64
#  54  Sliding Tackle    17067 non-null  float64
#  55  Goalkeeping       17125 non-null  int64
#  56  GK Diving         17125 non-null  int64
#  57  GK Handling       17125 non-null  int64
#  58  GK Kicking        17125 non-null  int64
#  59  GK Positioning    17125 non-null  int64
#  60  GK Reflexes       17125 non-null  int64
#  61  Total Stats       17125 non-null  int64
#  62  Base Stats        17125 non-null  int64
# dtypes: float64(13), int32(2), int64(37), object(11)
# memory usage: 8.1+ MB

# %%
# Fill NaN cells with 0 so we can perform calculations
fifa21 = fifa21.fillna(0)

# %%
fifa21.head()
# Out:
#           Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2      J. Cole   33   71                England  Coventry City   71  CAM
# 3     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3             0  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                 Flag Photo  ...  Standing Tackle  \
# 0      https://cdn.sofifa.com/flags/it.png  ...               69
# 1      https://cdn.sofifa.com/flags/es.png  ...               43
# 2  https://cdn.sofifa.com/flags/gb-eng.png  ...               34
# 3      https://cdn.sofifa.com/flags/tt.png  ...               41
# 4      https://cdn.sofifa.com/flags/es.png  ...               57
#
#   Sliding Tackle Goalkeeping  GK Diving  GK Handling  GK Kicking  \
# 0           69.0          56         14            5          15
# 1           40.0          56          9           12          13
# 2           30.0          51          9            6          13
# 3            0.0          68          5           21          64
# 4           56.0          45          6           13           6
#
#   GK Positioning GK Reflexes  Total Stats  Base Stats
# 0             10          12         1929         408
# 1             11          11         1906         385
# 2             16           7         1770         354
# 3             21          21         1348         369
# 4             13           7         2014         420
#
# [5 rows x 63 columns]

# %%
# Max scores for aggregate categories on original CSV:
# Attacking: 437, Skill: 470, Movement: 464, Power: 444, Mentality: 421, Defense: 272, Goalkeeping: 440

# Calculate new aggregates based on scores out of 100 so that they make more sense:

fifa21['attacking'] = (fifa21['Attacking'] / 4.37).round(1)
fifa21['skill'] = (fifa21['Skill'] / 4.70).round(1)
fifa21['movement'] = (fifa21['Movement'] / 4.64).round(1)
fifa21['power'] = (fifa21['Power'] / 4.44).round(1)
fifa21['mentality'] = (fifa21['Mentality'] / 4.21).round(1)
fifa21['defending'] = (fifa21['Defending'] / 2.72).round(1)
fifa21['goalkeeping'] = (fifa21['Goalkeeping'] / 4.40).round(1)
fifa21['attacking']
# Out:
# 0        71.6
# 1        77.1
# 2        77.1
# 3        60.4
# 4        84.0
#          ...
# 17120    45.1
# 17121    56.8
# 17122    49.9
# 17123    51.0
# 17124    58.1
# Name: attacking, Length: 17125, dtype: float64

# %%
# See if the max score for each skill group is 100 now:

print(fifa21['attacking'].max())
print(fifa21['skill'].max())
print(fifa21['movement'].max())
print(fifa21['power'].max())
print(fifa21['mentality'].max())
print(fifa21['defending'].max())
print(fifa21['goalkeeping'].max())
# Out:
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0

# %%
# Change to whole numbers, like Overall scores are:

fifa21['attacking'] = fifa21['attacking'].astype(int)
fifa21['skill'] = fifa21['skill'].astype(int)
fifa21['movement'] = fifa21['movement'].astype(int)
fifa21['power'] = fifa21['power'].astype(int)
fifa21['mentality'] = fifa21['mentality'].astype(int)
fifa21['defending'] = fifa21['defending'].astype(int)
fifa21['goalkeeping'] = fifa21['goalkeeping'].astype(int)
fifa21['attacking']
# Out:
# 0        71
# 1        77
# 2        77
# 3        60
# 4        84
#          ..
# 17120    45
# 17121    56
# 17122    49
# 17123    51
# 17124    58
# Name: attacking, Length: 17125, dtype: int32

# %%
print(fifa21['attacking'].max())
print(fifa21['skill'].max())
print(fifa21['movement'].max())
print(fifa21['power'].max())
print(fifa21['mentality'].max())
print(fifa21['defending'].max())
print(fifa21['goalkeeping'].max())
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
# Ended up not using these, but save just in case:

# Calculate the attributes based on the site Kim found
# (https://www.fifauteam.com/fifa-20-attributes-guide/#)

# Pace = Acceleration + Sprint Speed
# Shooting = Finishing + Long Shots + Penalties + Positioning + Shot Power + Volleys
# Passing = Crossing +   Curve + FK Accuracy + Long Passing + Short Passing + Vision
# Dribbling = Agility + Balance + Ball Control + Composure + Dribbling + Reactions
# Defending = Heading Accuracy + Interceptions + Marking + Sliding Tackle + Standing Tackle
# Physical = Aggression + Jumping + Stamina + Strength
# Goalkeeping = GK Diving + GK Handling + GK Kicking + GK Positioning + GK Reflexes


#fifa21['pace'] = fifa21['Acceleration'] + fifa21['Sprint Speed']
#fifa21['shooting'] = fifa21['Finishing'] + fifa21['Long Shots'] + fifa21['Penalties'] + fifa21['Positioning'] + \
#    fifa21['Shot Power'] + fifa21['Volleys']
#fifa21['passing'] = fifa21['Crossing'] + fifa21['Curve'] + fifa21['FK Accuracy'] + fifa21['Long Passing'] + \
#    fifa21['Short Passing'] + fifa21['Vision']
#fifa21['dribbling'] = fifa21['Agility'] + fifa21['Balance'] + fifa21['Ball Control'] + fifa21['Composure'] + fifa21['Dribbling'] \
#    + fifa21['Reactions']
#fifa21['defending'] = fifa21['Heading Accuracy'] + fifa21['Interceptions'] + fifa21['Marking'] + fifa21['Sliding Tackle'] + \
#    fifa21['Standing Tackle']
#fifa21['physical'] = fifa21['Aggression'] + fifa21['Jumping'] + fifa21['Stamina'] + fifa21['Strength']
#fifa21['goalkeeping2'] = fifa21['GK Diving'] + fifa21['GK Handling'] + fifa21['GK Kicking'] + fifa21['GK Positioning'] + \
#    fifa21['GK Reflexes']

# %%
# Look at which columns are left:

fifa21.columns
# Out:
# Index(['Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position',
#        'Player Photo', 'Flag Photo', 'POT', 'Team & Contract', 'Height',
#        'inches', 'Weight', 'bmi', 'foot', 'Joined', 'Value', 'Wage',
#        'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'attacking', 'skill', 'movement', 'power', 'mentality',
#        'defending', 'goalkeeping'],
#       dtype='object')

# %%
# Drop unneeded columns again:

useless_columns = ['Position', 'Joined', 'BOV', 'Team & Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
       'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve',
       'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
       'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
       'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
       'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
       'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
       'GK Kicking', 'GK Positioning', 'GK Reflexes']
fifa21 = fifa21.drop(useless_columns, axis = 1)
fifa21.head()
# Out:
#           Name  Age  OVA            Nationality           Club   BP  \
# 0  G. Pasquale   33   69                  Italy        Udinese  LWB
# 1  Luis García   37   71                  Spain      KAS Eupen   CM
# 2      J. Cole   33   71                England  Coventry City  CAM
# 3     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   ST
# 4      Iniesta   36   81                  Spain    Vissel Kobe  CAM
#
#                                         Player Photo  \
# 0  https://cdn.sofifa.com/players/000/002/16_120.png
# 1  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  https://cdn.sofifa.com/players/000/027/16_120.png
# 3  https://cdn.sofifa.com/players/000/036/09_120.png
# 4  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                 Flag Photo  POT Height  ...     Wage  \
# 0      https://cdn.sofifa.com/flags/it.png   69   6'0"  ...   7000.0
# 1      https://cdn.sofifa.com/flags/es.png   71  5'10"  ...   7000.0
# 2  https://cdn.sofifa.com/flags/gb-eng.png   71   5'9"  ...  15000.0
# 3      https://cdn.sofifa.com/flags/tt.png   82  5'11"  ...      0.0
# 4      https://cdn.sofifa.com/flags/es.png   81   5'7"  ...  12000.0
#
#    Total Stats  Base Stats attacking  skill  movement  power  mentality  \
# 0         1929         408        71     71        74     78         76
# 1         1906         385        77     78        65     73         86
# 2         1770         354        77     82        63     64         75
# 3         1348         369        60     54        37     53         64
# 4         2014         420        84     86        74     66         87
#
#    defending  goalkeeping
# 0         76           12
# 1         56           12
# 2         36           11
# 3         27           15
# 4         66           10
#
# [5 rows x 25 columns]

# %%
fifa21.columns
# Out:
# Index(['Name', 'Age', 'OVA', 'Nationality', 'Club', 'BP', 'Player Photo',
#        'Flag Photo', 'POT', 'Height', 'inches', 'Weight', 'bmi', 'foot',
#        'Value', 'Wage', 'Total Stats', 'Base Stats', 'attacking', 'skill',
#        'movement', 'power', 'mentality', 'defending', 'goalkeeping'],
#       dtype='object')

# %%
# Rename the columns to be sql-friendly

fifa21 = fifa21.rename(columns = {'Name':'name', 'Age':'age', 'OVA':'overall', 'Nationality':'nationality', \
        'Club':'club', 'BP':'bestposition',  'Player Photo':'playerphoto', 'Flag Photo':'flagphoto',\
        'POT':'potential', 'Height':'height', 'Weight':'weight', 'Value':'value',\
        'Wage':'wage',  'Total Stats':'totalstats', 'Base Stats':'basestats'})

# %%
fifa21.head()
# Out:
#           name  age  overall            nationality           club  \
# 0  G. Pasquale   33       69                  Italy        Udinese
# 1  Luis García   37       71                  Spain      KAS Eupen
# 2      J. Cole   33       71                England  Coventry City
# 3     D. Yorke   36       68  Trinidad &amp; Tobago     Sunderland
# 4      Iniesta   36       81                  Spain    Vissel Kobe
#
#   bestposition                                        playerphoto  \
# 0          LWB  https://cdn.sofifa.com/players/000/002/16_120.png
# 1           CM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2          CAM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           ST  https://cdn.sofifa.com/players/000/036/09_120.png
# 4          CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                  flagphoto  potential height  ...     wage  \
# 0      https://cdn.sofifa.com/flags/it.png         69   6'0"  ...   7000.0
# 1      https://cdn.sofifa.com/flags/es.png         71  5'10"  ...   7000.0
# 2  https://cdn.sofifa.com/flags/gb-eng.png         71   5'9"  ...  15000.0
# 3      https://cdn.sofifa.com/flags/tt.png         82  5'11"  ...      0.0
# 4      https://cdn.sofifa.com/flags/es.png         81   5'7"  ...  12000.0
#
#    totalstats  basestats attacking  skill  movement  power  mentality  \
# 0        1929        408        71     71        74     78         76
# 1        1906        385        77     78        65     73         86
# 2        1770        354        77     82        63     64         75
# 3        1348        369        60     54        37     53         64
# 4        2014        420        84     86        74     66         87
#
#    defending  goalkeeping
# 0         76           12
# 1         56           12
# 2         36           11
# 3         27           15
# 4         66           10
#
# [5 rows x 25 columns]

# %%
fifa21.columns
# Out:
# Index(['name', 'age', 'overall', 'nationality', 'club', 'bestposition',
#        'playerphoto', 'flagphoto', 'potential', 'height', 'inches', 'weight',
#        'bmi', 'foot', 'value', 'wage', 'totalstats', 'basestats', 'attacking',
#        'skill', 'movement', 'power', 'mentality', 'defending', 'goalkeeping'],
#       dtype='object')

# %%
fifa21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17125 entries, 0 to 17124
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          17125 non-null  object
#  1   age           17125 non-null  int64
#  2   overall       17125 non-null  int64
#  3   nationality   17125 non-null  object
#  4   club          17125 non-null  object
#  5   bestposition  17125 non-null  object
#  6   playerphoto   17125 non-null  object
#  7   flagphoto     17125 non-null  object
#  8   potential     17125 non-null  int64
#  9   height        17125 non-null  object
#  10  inches        17125 non-null  int32
#  11  weight        17125 non-null  int32
#  12  bmi           17125 non-null  float64
#  13  foot          17125 non-null  object
#  14  value         17125 non-null  float64
#  15  wage          17125 non-null  float64
#  16  totalstats    17125 non-null  int64
#  17  basestats     17125 non-null  int64
#  18  attacking     17125 non-null  int32
#  19  skill         17125 non-null  int32
#  20  movement      17125 non-null  int32
#  21  power         17125 non-null  int32
#  22  mentality     17125 non-null  int32
#  23  defending     17125 non-null  int32
#  24  goalkeeping   17125 non-null  int32
# dtypes: float64(3), int32(9), int64(5), object(8)
# memory usage: 2.7+ MB

# %%
fifa21.head()
# Out:
#           name  age  overall            nationality           club  \
# 0  G. Pasquale   33       69                  Italy        Udinese
# 1  Luis García   37       71                  Spain      KAS Eupen
# 2      J. Cole   33       71                England  Coventry City
# 3     D. Yorke   36       68  Trinidad &amp; Tobago     Sunderland
# 4      Iniesta   36       81                  Spain    Vissel Kobe
#
#   bestposition                                        playerphoto  \
# 0          LWB  https://cdn.sofifa.com/players/000/002/16_120.png
# 1           CM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2          CAM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           ST  https://cdn.sofifa.com/players/000/036/09_120.png
# 4          CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                  flagphoto  potential height  ...     wage  \
# 0      https://cdn.sofifa.com/flags/it.png         69   6'0"  ...   7000.0
# 1      https://cdn.sofifa.com/flags/es.png         71  5'10"  ...   7000.0
# 2  https://cdn.sofifa.com/flags/gb-eng.png         71   5'9"  ...  15000.0
# 3      https://cdn.sofifa.com/flags/tt.png         82  5'11"  ...      0.0
# 4      https://cdn.sofifa.com/flags/es.png         81   5'7"  ...  12000.0
#
#    totalstats  basestats attacking  skill  movement  power  mentality  \
# 0        1929        408        71     71        74     78         76
# 1        1906        385        77     78        65     73         86
# 2        1770        354        77     82        63     64         75
# 3        1348        369        60     54        37     53         64
# 4        2014        420        84     86        74     66         87
#
#    defending  goalkeeping
# 0         76           12
# 1         56           12
# 2         36           11
# 3         27           15
# 4         66           10
#
# [5 rows x 25 columns]

# %%
# Save a cleaned version of the file:

fifa21.to_csv("fifa21.csv", encoding="utf-8", index=False, header=True)
