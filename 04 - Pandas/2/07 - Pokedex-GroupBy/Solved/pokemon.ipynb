# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Save file path to variable
pokemon_csv = "Resources/Pokemon.csv"

# %%
# Read with Pandas
pokemon_df = pd.read_csv(pokemon_csv)
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Extract the following columns: "Type 1", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", and "Speed"
pokemon_type_df = pokemon_df[["Type 1", "HP", "Attack", "Defense",
                            "Sp. Atk", "Sp. Def", "Speed"]]
pokemon_type_df.head()
# Out:
#   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  Grass  45      49       49       65       65     45
# 1  Grass  60      62       63       80       80     60
# 2  Grass  80      82       83      100      100     80
# 3  Grass  80     100      123      122      120     80
# 4   Fire  39      52       43       60       50     65

# %%
# Create a dataframe of the average stats for each type of pokemon.
pokemon_group = pokemon_type_df.groupby(["Type 1"])

pokemon_comparison_df = pokemon_group.mean()
pokemon_comparison_df
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed
# Type 1
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting  69.851852   96.777778   65.925926  53.111111  64.703704   66.074074
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# ...

# %%
# Calculate the total power level of each type of pokemon by summing all of the stats together.
# Place the results into a new column.
pokemon_comparison_df["Total"] = pokemon_comparison_df.sum(axis=1)

pokemon_comparison_df["Total"]
# Out:
# Type 1
# Bug         378.927536
# Dark        445.741935
# Dragon      550.531250
# Electric    443.409091
# Fairy       413.176471
# Fighting    416.444444
# Fire        458.076923
# Flying      485.000000
# Ghost       439.562500
# Grass       421.142857
# Ground      437.500000
# Ice         433.458333
# Normal      401.683673
# Poison      399.142857
# Psychic     475.947368
# Rock        453.750000
# Steel       487.703704
# Water       430.455357
# Name: Total, dtype: float64

# %%
# Bonus: Sort the table by strongest type and export the resulting table to a new CSV.
strongest_pokemon_df = pokemon_comparison_df.sort_values(["Total"], ascending=False)
strongest_pokemon_df.to_csv("output/pokemon_rankings.csv", index=True)

# %%
strongest_pokemon_df
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed  \
# Type 1
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Steel     65.222222   92.703704  126.370370  67.518519  80.629630   55.259259
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Psychic   70.631579   71.456140   67.684211  98.403509  86.280702   81.491228
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Rock      65.363636   92.863636  100.795455  63.340909  75.477273   55.909091
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# Ice       72.000000   72.750000   71.416667  77.541667  76.291667   63.458333
# ...

# %%
pokemon_comparison_df.style.background_gradient(cmap = 'viridis')
# Out:
# <style  type="text/css" >
#     #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col1 {
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }    #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col2 {
#             background-color:  #453882;
#             color:  #f1f1f1;
#         }    #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col3 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col4 {
#             background-color:  #481d6f;
#             color:  #f1f1f1;
#         }    #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col5 {
#             background-color:  #3c508b;
#             color:  #f1f1f1;
#         }    #T_e95ec664_4540_11eb_8df7_ac7ba146b715row0_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
# ...
