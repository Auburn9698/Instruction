# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data


plt.bar(x_axis, bars_in_cities, color = 'g', alpha = 0.6, align = 'center')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x1698774c9d0>,
#   <matplotlib.axis.XTick at 0x1698774c9a0>,
#   <matplotlib.axis.XTick at 0x1698772a730>,
#   <matplotlib.axis.XTick at 0x16987e47130>,
#   <matplotlib.axis.XTick at 0x16987e47640>],
#  [Text(-1.0, 0, 'New Orleans'),
#   Text(0.0, 0, 'Milwaukee'),
#   Text(1.0, 0, 'Omaha'),
#   Text(2.0, 0, 'Pittsburgh'),
#   Text(3.0, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities) + 0.4)
# Out:
# (0.0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.title("Number of Bars in Cities")
plt.xlabel("City")
plt.ylabel("Number of Bars")
# Out:
# Text(50.24999845690197, 0.5, 'Number of Bars')

# %%
# Bonus new yticks

plt.yticks([2.5, 5, 7.5], ["Not Many", "Moderate", "Many"], rotation = 'vertical'  )
# Out:
# ([<matplotlib.axis.YTick at 0x16987df0220>,
#   <matplotlib.axis.YTick at 0x1698774ce20>,
#   <matplotlib.axis.YTick at 0x16987e4c5b0>],
#  [Text(0, 0.0, 'Not Many'), Text(0, 1.0, 'Moderate'), Text(0, 2.0, 'Many')])
